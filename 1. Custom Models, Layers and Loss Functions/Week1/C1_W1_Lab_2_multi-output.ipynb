# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 217.2659 - y1_output_loss: 108.9230 - y2_output_loss: 107.4512 - y1_output_root_mean_squared_error: 10.4670 - y2_output_root_mean_squared_error: 10.3783 - val_loss: 76.5223 - val_y1_output_loss: 17.1091 - val_y2_output_loss: 59.4218 - val_y1_output_root_mean_squared_error: 4.1628 - val_y2_output_root_mean_squared_error: 7.6937
# Epoch 2/500
# 614/614 [==============================] - 0s 147us/sample - loss: 30.0435 - y1_output_loss: 12.4713 - y2_output_loss: 17.6631 - y1_output_root_mean_squared_error: 3.5331 - y2_output_root_mean_squared_error: 4.1905 - val_loss: 82.7948 - val_y1_output_loss: 18.7242 - val_y2_output_loss: 63.2113 - val_y1_output_root_mean_squared_error: 4.3569 - val_y2_output_root_mean_squared_error: 7.9883
# Epoch 3/500
# 614/614 [==============================] - 0s 152us/sample - loss: 24.1693 - y1_output_loss: 10.3617 - y2_output_loss: 13.7524 - y1_output_root_mean_squared_error: 3.2212 - y2_output_root_mean_squared_error: 3.7139 - val_loss: 26.4295 - val_y1_output_loss: 8.6453 - val_y2_output_loss: 17.3532 - val_y1_output_root_mean_squared_error: 2.9767 - val_y2_output_root_mean_squared_error: 4.1915
# Epoch 4/500
# 614/614 [==============================] - 0s 142us/sample - loss: 22.0504 - y1_output_loss: 9.3499 - y2_output_loss: 13.7323 - y1_output_root_mean_squared_error: 3.0091 - y2_output_root_mean_squared_error: 3.6050 - val_loss: 95.3767 - val_y1_output_loss: 23.7660 - val_y2_output_loss: 71.4256 - val_y1_output_root_mean_squared_error: 4.9142 - val_y2_output_root_mean_squared_error: 8.4397
# Epoch 5/500
# 614/614 [==============================] - 0s 141us/sample - loss: 26.3246 - y1_output_loss: 9.6612 - y2_output_loss: 16.5013 - y1_output_root_mean_squared_error: 3.1199 - y2_output_root_mean_squared_error: 4.0731 - val_loss: 26.8827 - val_y1_output_loss: 9.5060 - val_y2_output_loss: 16.6476 - val_y1_output_root_mean_squared_error: 3.1268 - val_y2_output_root_mean_squared_error: 4.1359
# Epoch 6/500
# 614/614 [==============================] - 0s 146us/sample - loss: 22.6085 - y1_output_loss: 8.9121 - y2_output_loss: 13.7336 - y1_output_root_mean_squared_error: 2.9912 - y2_output_root_mean_squared_error: 3.6961 - val_loss: 57.4633 - val_y1_output_loss: 16.1911 - val_y2_output_loss: 41.8050 - val_y1_output_root_mean_squared_error: 4.0336 - val_y2_output_root_mean_squared_error: 6.4182
# Epoch 7/500
# 614/614 [==============================] - 0s 142us/sample - loss: 23.1673 - y1_output_loss: 9.5614 - y2_output_loss: 13.5093 - y1_output_root_mean_squared_error: 3.0925 - y2_output_root_mean_squared_error: 3.6883 - val_loss: 29.1209 - val_y1_output_loss: 11.1835 - val_y2_output_loss: 17.5699 - val_y1_output_root_mean_squared_error: 3.3885 - val_y2_output_root_mean_squared_error: 4.1999
# Epoch 8/500
# 614/614 [==============================] - 0s 140us/sample - loss: 22.8181 - y1_output_loss: 8.9017 - y2_output_loss: 14.1953 - y1_output_root_mean_squared_error: 2.9755 - y2_output_root_mean_squared_error: 3.7369 - val_loss: 85.9748 - val_y1_output_loss: 14.1774 - val_y2_output_loss: 71.7820 - val_y1_output_root_mean_squared_error: 3.7609 - val_y2_output_root_mean_squared_error: 8.4753
# Epoch 9/500
# 614/614 [==============================] - 0s 142us/sample - loss: 29.2851 - y1_output_loss: 9.2481 - y2_output_loss: 19.7584 - y1_output_root_mean_squared_error: 3.0554 - y2_output_root_mean_squared_error: 4.4665 - val_loss: 19.9869 - val_y1_output_loss: 8.5361 - val_y2_output_loss: 11.0473 - val_y1_output_root_mean_squared_error: 2.9490 - val_y2_output_root_mean_squared_error: 3.3601
# Epoch 10/500
# 614/614 [==============================] - 0s 133us/sample - loss: 19.3261 - y1_output_loss: 7.9055 - y2_output_loss: 11.3090 - y1_output_root_mean_squared_error: 2.8223 - y2_output_root_mean_squared_error: 3.3705 - val_loss: 19.3749 - val_y1_output_loss: 7.8088 - val_y2_output_loss: 11.1866 - val_y1_output_root_mean_squared_error: 2.8396 - val_y2_output_root_mean_squared_error: 3.3633
# Epoch 11/500
# 614/614 [==============================] - 0s 134us/sample - loss: 21.1513 - y1_output_loss: 8.2292 - y2_output_loss: 12.7575 - y1_output_root_mean_squared_error: 2.8791 - y2_output_root_mean_squared_error: 3.5864 - val_loss: 18.3879 - val_y1_output_loss: 6.8155 - val_y2_output_loss: 11.2786 - val_y1_output_root_mean_squared_error: 2.6387 - val_y2_output_root_mean_squared_error: 3.3801
# Epoch 12/500
# 614/614 [==============================] - 0s 136us/sample - loss: 19.4355 - y1_output_loss: 7.5717 - y2_output_loss: 11.7934 - y1_output_root_mean_squared_error: 2.7592 - y2_output_root_mean_squared_error: 3.4384 - val_loss: 22.2899 - val_y1_output_loss: 7.8515 - val_y2_output_loss: 13.7494 - val_y1_output_root_mean_squared_error: 2.8461 - val_y2_output_root_mean_squared_error: 3.7669
# Epoch 13/500
# 614/614 [==============================] - 0s 137us/sample - loss: 21.9086 - y1_output_loss: 8.2239 - y2_output_loss: 13.5325 - y1_output_root_mean_squared_error: 2.8782 - y2_output_root_mean_squared_error: 3.6911 - val_loss: 16.8635 - val_y1_output_loss: 6.1298 - val_y2_output_loss: 10.3304 - val_y1_output_root_mean_squared_error: 2.5114 - val_y2_output_root_mean_squared_error: 3.2491
# Epoch 14/500
# 614/614 [==============================] - 0s 132us/sample - loss: 18.2103 - y1_output_loss: 7.2703 - y2_output_loss: 10.9403 - y1_output_root_mean_squared_error: 2.6942 - y2_output_root_mean_squared_error: 3.3093 - val_loss: 15.1716 - val_y1_output_loss: 5.7992 - val_y2_output_loss: 9.0479 - val_y1_output_root_mean_squared_error: 2.4414 - val_y2_output_root_mean_squared_error: 3.0350
# Epoch 15/500
# 614/614 [==============================] - 0s 133us/sample - loss: 17.6558 - y1_output_loss: 6.8951 - y2_output_loss: 11.0437 - y1_output_root_mean_squared_error: 2.6087 - y2_output_root_mean_squared_error: 3.2940 - val_loss: 87.5082 - val_y1_output_loss: 21.8778 - val_y2_output_loss: 66.0502 - val_y1_output_root_mean_squared_error: 4.7036 - val_y2_output_root_mean_squared_error: 8.0861
# Epoch 16/500
# 614/614 [==============================] - 0s 133us/sample - loss: 19.9081 - y1_output_loss: 7.2688 - y2_output_loss: 12.4823 - y1_output_root_mean_squared_error: 2.7031 - y2_output_root_mean_squared_error: 3.5498 - val_loss: 14.2905 - val_y1_output_loss: 5.6331 - val_y2_output_loss: 8.3271 - val_y1_output_root_mean_squared_error: 2.4084 - val_y2_output_root_mean_squared_error: 2.9138
# Epoch 17/500
# 614/614 [==============================] - 0s 134us/sample - loss: 15.4249 - y1_output_loss: 5.9278 - y2_output_loss: 9.4054 - y1_output_root_mean_squared_error: 2.4395 - y2_output_root_mean_squared_error: 3.0779 - val_loss: 13.9824 - val_y1_output_loss: 5.5296 - val_y2_output_loss: 8.1659 - val_y1_output_root_mean_squared_error: 2.3919 - val_y2_output_root_mean_squared_error: 2.8743
# Epoch 18/500
# 614/614 [==============================] - 0s 134us/sample - loss: 18.9768 - y1_output_loss: 7.0054 - y2_output_loss: 11.8381 - y1_output_root_mean_squared_error: 2.6522 - y2_output_root_mean_squared_error: 3.4558 - val_loss: 22.9324 - val_y1_output_loss: 8.5044 - val_y2_output_loss: 14.3754 - val_y1_output_root_mean_squared_error: 2.9498 - val_y2_output_root_mean_squared_error: 3.7724
# Epoch 19/500
# 614/614 [==============================] - 0s 133us/sample - loss: 14.5144 - y1_output_loss: 5.7829 - y2_output_loss: 8.6685 - y1_output_root_mean_squared_error: 2.4050 - y2_output_root_mean_squared_error: 2.9547 - val_loss: 17.2051 - val_y1_output_loss: 6.7262 - val_y2_output_loss: 10.1069 - val_y1_output_root_mean_squared_error: 2.6109 - val_y2_output_root_mean_squared_error: 3.2231
# Epoch 20/500
# 614/614 [==============================] - 0s 134us/sample - loss: 14.9971 - y1_output_loss: 5.8695 - y2_output_loss: 9.4349 - y1_output_root_mean_squared_error: 2.4042 - y2_output_root_mean_squared_error: 3.0359 - val_loss: 33.9667 - val_y1_output_loss: 6.8215 - val_y2_output_loss: 26.8609 - val_y1_output_root_mean_squared_error: 2.6611 - val_y2_output_root_mean_squared_error: 5.1851
# Epoch 21/500
# 614/614 [==============================] - 0s 135us/sample - loss: 14.9146 - y1_output_loss: 5.6837 - y2_output_loss: 9.1876 - y1_output_root_mean_squared_error: 2.3853 - y2_output_root_mean_squared_error: 3.0372 - val_loss: 12.2391 - val_y1_output_loss: 5.0432 - val_y2_output_loss: 6.9123 - val_y1_output_root_mean_squared_error: 2.2857 - val_y2_output_root_mean_squared_error: 2.6485
# Epoch 22/500
# 614/614 [==============================] - 0s 139us/sample - loss: 13.6823 - y1_output_loss: 5.2542 - y2_output_loss: 8.4638 - y1_output_root_mean_squared_error: 2.2990 - y2_output_root_mean_squared_error: 2.8977 - val_loss: 16.6738 - val_y1_output_loss: 4.6792 - val_y2_output_loss: 11.5226 - val_y1_output_root_mean_squared_error: 2.1960 - val_y2_output_root_mean_squared_error: 3.4426
# Epoch 23/500
# 614/614 [==============================] - 0s 144us/sample - loss: 12.9283 - y1_output_loss: 4.9724 - y2_output_loss: 8.3280 - y1_output_root_mean_squared_error: 2.2188 - y2_output_root_mean_squared_error: 2.8294 - val_loss: 109.6909 - val_y1_output_loss: 27.1153 - val_y2_output_loss: 85.1725 - val_y1_output_root_mean_squared_error: 5.1534 - val_y2_output_root_mean_squared_error: 9.1177
# Epoch 24/500
# 614/614 [==============================] - 0s 140us/sample - loss: 13.9471 - y1_output_loss: 4.9906 - y2_output_loss: 8.8696 - y1_output_root_mean_squared_error: 2.2388 - y2_output_root_mean_squared_error: 2.9891 - val_loss: 12.9336 - val_y1_output_loss: 5.5484 - val_y2_output_loss: 7.3283 - val_y1_output_root_mean_squared_error: 2.3890 - val_y2_output_root_mean_squared_error: 2.6882
# Epoch 25/500
# 614/614 [==============================] - 0s 135us/sample - loss: 12.2361 - y1_output_loss: 4.4056 - y2_output_loss: 7.9192 - y1_output_root_mean_squared_error: 2.1008 - y2_output_root_mean_squared_error: 2.7969 - val_loss: 18.8389 - val_y1_output_loss: 5.6770 - val_y2_output_loss: 13.1272 - val_y1_output_root_mean_squared_error: 2.3993 - val_y2_output_root_mean_squared_error: 3.6169
# Epoch 26/500
# 614/614 [==============================] - 0s 136us/sample - loss: 11.6144 - y1_output_loss: 4.2365 - y2_output_loss: 7.4381 - y1_output_root_mean_squared_error: 2.0435 - y2_output_root_mean_squared_error: 2.7274 - val_loss: 16.3994 - val_y1_output_loss: 6.2809 - val_y2_output_loss: 10.2993 - val_y1_output_root_mean_squared_error: 2.5220 - val_y2_output_root_mean_squared_error: 3.1684
# Epoch 27/500
# 614/614 [==============================] - 0s 135us/sample - loss: 9.5597 - y1_output_loss: 3.7251 - y2_output_loss: 5.8557 - y1_output_root_mean_squared_error: 1.9277 - y2_output_root_mean_squared_error: 2.4174 - val_loss: 13.4743 - val_y1_output_loss: 5.6701 - val_y2_output_loss: 7.9922 - val_y1_output_root_mean_squared_error: 2.3940 - val_y2_output_root_mean_squared_error: 2.7826
# Epoch 28/500
# 614/614 [==============================] - 0s 132us/sample - loss: 11.8754 - y1_output_loss: 4.2538 - y2_output_loss: 7.7478 - y1_output_root_mean_squared_error: 2.0544 - y2_output_root_mean_squared_error: 2.7667 - val_loss: 10.8205 - val_y1_output_loss: 3.9831 - val_y2_output_loss: 6.6711 - val_y1_output_root_mean_squared_error: 2.0180 - val_y2_output_root_mean_squared_error: 2.5977
# Epoch 29/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.2938 - y1_output_loss: 3.3384 - y2_output_loss: 5.8754 - y1_output_root_mean_squared_error: 1.8355 - y2_output_root_mean_squared_error: 2.4341 - val_loss: 10.0595 - val_y1_output_loss: 3.5059 - val_y2_output_loss: 6.5064 - val_y1_output_root_mean_squared_error: 1.9047 - val_y2_output_root_mean_squared_error: 2.5361
# Epoch 30/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.6393 - y1_output_loss: 3.5761 - y2_output_loss: 6.2322 - y1_output_root_mean_squared_error: 1.8792 - y2_output_root_mean_squared_error: 2.4714 - val_loss: 54.3983 - val_y1_output_loss: 14.0226 - val_y2_output_loss: 41.8101 - val_y1_output_root_mean_squared_error: 3.7170 - val_y2_output_root_mean_squared_error: 6.3704
# Epoch 31/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.0554 - y1_output_loss: 3.3027 - y2_output_loss: 5.7606 - y1_output_root_mean_squared_error: 1.8222 - y2_output_root_mean_squared_error: 2.3947 - val_loss: 16.0411 - val_y1_output_loss: 5.5849 - val_y2_output_loss: 10.0106 - val_y1_output_root_mean_squared_error: 2.3909 - val_y2_output_root_mean_squared_error: 3.2132
# Epoch 32/500
# 614/614 [==============================] - 0s 133us/sample - loss: 8.5260 - y1_output_loss: 3.0259 - y2_output_loss: 5.5144 - y1_output_root_mean_squared_error: 1.7432 - y2_output_root_mean_squared_error: 2.3425 - val_loss: 13.7744 - val_y1_output_loss: 3.1738 - val_y2_output_loss: 10.2014 - val_y1_output_root_mean_squared_error: 1.8142 - val_y2_output_root_mean_squared_error: 3.2377
# Epoch 33/500
# 614/614 [==============================] - 0s 168us/sample - loss: 11.4872 - y1_output_loss: 3.7840 - y2_output_loss: 7.5998 - y1_output_root_mean_squared_error: 1.9534 - y2_output_root_mean_squared_error: 2.7697 - val_loss: 13.7705 - val_y1_output_loss: 4.7573 - val_y2_output_loss: 8.5977 - val_y1_output_root_mean_squared_error: 2.2152 - val_y2_output_root_mean_squared_error: 2.9771
# Epoch 34/500
# 614/614 [==============================] - 0s 145us/sample - loss: 9.0096 - y1_output_loss: 2.9460 - y2_output_loss: 6.0637 - y1_output_root_mean_squared_error: 1.7243 - y2_output_root_mean_squared_error: 2.4569 - val_loss: 13.2507 - val_y1_output_loss: 3.5384 - val_y2_output_loss: 9.3961 - val_y1_output_root_mean_squared_error: 1.9072 - val_y2_output_root_mean_squared_error: 3.1005
# Epoch 35/500
# 614/614 [==============================] - 0s 144us/sample - loss: 8.5446 - y1_output_loss: 2.9813 - y2_output_loss: 5.5496 - y1_output_root_mean_squared_error: 1.7173 - y2_output_root_mean_squared_error: 2.3655 - val_loss: 8.6872 - val_y1_output_loss: 2.7226 - val_y2_output_loss: 5.7448 - val_y1_output_root_mean_squared_error: 1.6787 - val_y2_output_root_mean_squared_error: 2.4226
# Epoch 36/500
# 614/614 [==============================] - 0s 140us/sample - loss: 9.5965 - y1_output_loss: 3.0143 - y2_output_loss: 6.5661 - y1_output_root_mean_squared_error: 1.7373 - y2_output_root_mean_squared_error: 2.5649 - val_loss: 11.3331 - val_y1_output_loss: 3.6214 - val_y2_output_loss: 7.3698 - val_y1_output_root_mean_squared_error: 1.9368 - val_y2_output_root_mean_squared_error: 2.7535
# Epoch 37/500
# 614/614 [==============================] - 0s 140us/sample - loss: 9.5939 - y1_output_loss: 3.0000 - y2_output_loss: 6.5364 - y1_output_root_mean_squared_error: 1.7389 - y2_output_root_mean_squared_error: 2.5632 - val_loss: 18.8443 - val_y1_output_loss: 3.5989 - val_y2_output_loss: 14.7655 - val_y1_output_root_mean_squared_error: 1.9238 - val_y2_output_root_mean_squared_error: 3.8914
# Epoch 38/500
# 614/614 [==============================] - 0s 141us/sample - loss: 9.3417 - y1_output_loss: 2.8415 - y2_output_loss: 6.4685 - y1_output_root_mean_squared_error: 1.6876 - y2_output_root_mean_squared_error: 2.5483 - val_loss: 6.7279 - val_y1_output_loss: 2.2083 - val_y2_output_loss: 4.5663 - val_y1_output_root_mean_squared_error: 1.5109 - val_y2_output_root_mean_squared_error: 2.1083
# Epoch 39/500
# 614/614 [==============================] - 0s 139us/sample - loss: 7.3854 - y1_output_loss: 2.5371 - y2_output_loss: 4.9273 - y1_output_root_mean_squared_error: 1.5992 - y2_output_root_mean_squared_error: 2.1972 - val_loss: 22.6224 - val_y1_output_loss: 5.1348 - val_y2_output_loss: 17.5452 - val_y1_output_root_mean_squared_error: 2.2464 - val_y2_output_root_mean_squared_error: 4.1924
# Epoch 40/500
# 614/614 [==============================] - 0s 152us/sample - loss: 9.6326 - y1_output_loss: 3.1102 - y2_output_loss: 6.4505 - y1_output_root_mean_squared_error: 1.7700 - y2_output_root_mean_squared_error: 2.5494 - val_loss: 17.7644 - val_y1_output_loss: 3.9621 - val_y2_output_loss: 13.2854 - val_y1_output_root_mean_squared_error: 2.0180 - val_y2_output_root_mean_squared_error: 3.7003
# Epoch 41/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.5144 - y1_output_loss: 2.6802 - y2_output_loss: 5.8375 - y1_output_root_mean_squared_error: 1.6319 - y2_output_root_mean_squared_error: 2.4190 - val_loss: 15.7578 - val_y1_output_loss: 5.0411 - val_y2_output_loss: 10.4740 - val_y1_output_root_mean_squared_error: 2.2589 - val_y2_output_root_mean_squared_error: 3.2642
# Epoch 42/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.1012 - y1_output_loss: 2.9033 - y2_output_loss: 6.1165 - y1_output_root_mean_squared_error: 1.7109 - y2_output_root_mean_squared_error: 2.4848 - val_loss: 7.6449 - val_y1_output_loss: 2.4811 - val_y2_output_loss: 5.2584 - val_y1_output_root_mean_squared_error: 1.5912 - val_y2_output_root_mean_squared_error: 2.2612
# Epoch 43/500
# 614/614 [==============================] - 0s 136us/sample - loss: 8.0196 - y1_output_loss: 2.5363 - y2_output_loss: 5.4316 - y1_output_root_mean_squared_error: 1.5928 - y2_output_root_mean_squared_error: 2.3415 - val_loss: 6.4599 - val_y1_output_loss: 2.0567 - val_y2_output_loss: 4.3821 - val_y1_output_root_mean_squared_error: 1.4560 - val_y2_output_root_mean_squared_error: 2.0832
# Epoch 44/500
# 614/614 [==============================] - 0s 138us/sample - loss: 8.4941 - y1_output_loss: 2.4069 - y2_output_loss: 6.1261 - y1_output_root_mean_squared_error: 1.5411 - y2_output_root_mean_squared_error: 2.4737 - val_loss: 36.0471 - val_y1_output_loss: 13.2535 - val_y2_output_loss: 22.8734 - val_y1_output_root_mean_squared_error: 3.6197 - val_y2_output_root_mean_squared_error: 4.7901
# Epoch 45/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.2843 - y1_output_loss: 2.2496 - y2_output_loss: 4.9854 - y1_output_root_mean_squared_error: 1.5058 - y2_output_root_mean_squared_error: 2.2399 - val_loss: 7.5949 - val_y1_output_loss: 2.2615 - val_y2_output_loss: 5.5097 - val_y1_output_root_mean_squared_error: 1.5238 - val_y2_output_root_mean_squared_error: 2.2963
# Epoch 46/500
# 614/614 [==============================] - 0s 139us/sample - loss: 9.2800 - y1_output_loss: 2.5932 - y2_output_loss: 6.6463 - y1_output_root_mean_squared_error: 1.6037 - y2_output_root_mean_squared_error: 2.5900 - val_loss: 6.6368 - val_y1_output_loss: 1.9539 - val_y2_output_loss: 4.5855 - val_y1_output_root_mean_squared_error: 1.4232 - val_y2_output_root_mean_squared_error: 2.1474
# Epoch 47/500
# 614/614 [==============================] - 0s 149us/sample - loss: 7.4986 - y1_output_loss: 2.4406 - y2_output_loss: 5.0377 - y1_output_root_mean_squared_error: 1.5652 - y2_output_root_mean_squared_error: 2.2469 - val_loss: 12.6547 - val_y1_output_loss: 2.4007 - val_y2_output_loss: 9.9060 - val_y1_output_root_mean_squared_error: 1.5626 - val_y2_output_root_mean_squared_error: 3.1958
# Epoch 48/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.1974 - y1_output_loss: 1.9168 - y2_output_loss: 4.2570 - y1_output_root_mean_squared_error: 1.3885 - y2_output_root_mean_squared_error: 2.0663 - val_loss: 8.8342 - val_y1_output_loss: 2.1388 - val_y2_output_loss: 6.9425 - val_y1_output_root_mean_squared_error: 1.4790 - val_y2_output_root_mean_squared_error: 2.5781
# Epoch 49/500
# 614/614 [==============================] - 0s 143us/sample - loss: 5.9744 - y1_output_loss: 1.9333 - y2_output_loss: 4.1009 - y1_output_root_mean_squared_error: 1.3863 - y2_output_root_mean_squared_error: 2.0131 - val_loss: 18.1078 - val_y1_output_loss: 3.2368 - val_y2_output_loss: 14.3457 - val_y1_output_root_mean_squared_error: 1.8252 - val_y2_output_root_mean_squared_error: 3.8440
# Epoch 50/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.7913 - y1_output_loss: 2.0903 - y2_output_loss: 4.7655 - y1_output_root_mean_squared_error: 1.4453 - y2_output_root_mean_squared_error: 2.1685 - val_loss: 29.1653 - val_y1_output_loss: 5.7186 - val_y2_output_loss: 22.6843 - val_y1_output_root_mean_squared_error: 2.4286 - val_y2_output_root_mean_squared_error: 4.8236
# Epoch 51/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.4109 - y1_output_loss: 2.1481 - y2_output_loss: 5.1964 - y1_output_root_mean_squared_error: 1.4720 - y2_output_root_mean_squared_error: 2.2900 - val_loss: 7.3752 - val_y1_output_loss: 1.8024 - val_y2_output_loss: 5.4966 - val_y1_output_root_mean_squared_error: 1.3605 - val_y2_output_root_mean_squared_error: 2.3504
# Epoch 52/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.5900 - y1_output_loss: 1.8224 - y2_output_loss: 4.7620 - y1_output_root_mean_squared_error: 1.3485 - y2_output_root_mean_squared_error: 2.1844 - val_loss: 6.8734 - val_y1_output_loss: 2.6931 - val_y2_output_loss: 4.3916 - val_y1_output_root_mean_squared_error: 1.6472 - val_y2_output_root_mean_squared_error: 2.0397
# Epoch 53/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.9557 - y1_output_loss: 1.8538 - y2_output_loss: 4.2017 - y1_output_root_mean_squared_error: 1.3470 - y2_output_root_mean_squared_error: 2.0350 - val_loss: 15.3931 - val_y1_output_loss: 5.1373 - val_y2_output_loss: 10.5879 - val_y1_output_root_mean_squared_error: 2.2752 - val_y2_output_root_mean_squared_error: 3.1964
# Epoch 54/500
# 614/614 [==============================] - 0s 182us/sample - loss: 7.1274 - y1_output_loss: 2.1530 - y2_output_loss: 4.9853 - y1_output_root_mean_squared_error: 1.4730 - y2_output_root_mean_squared_error: 2.2266 - val_loss: 10.8391 - val_y1_output_loss: 2.9790 - val_y2_output_loss: 7.5991 - val_y1_output_root_mean_squared_error: 1.7486 - val_y2_output_root_mean_squared_error: 2.7896
# Epoch 55/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.1684 - y1_output_loss: 1.5449 - y2_output_loss: 3.6511 - y1_output_root_mean_squared_error: 1.2441 - y2_output_root_mean_squared_error: 1.9028 - val_loss: 13.9532 - val_y1_output_loss: 1.9966 - val_y2_output_loss: 12.6018 - val_y1_output_root_mean_squared_error: 1.4156 - val_y2_output_root_mean_squared_error: 3.4568
# Epoch 56/500
# 614/614 [==============================] - 0s 152us/sample - loss: 7.0895 - y1_output_loss: 1.9849 - y2_output_loss: 5.1140 - y1_output_root_mean_squared_error: 1.4065 - y2_output_root_mean_squared_error: 2.2608 - val_loss: 12.9085 - val_y1_output_loss: 3.7557 - val_y2_output_loss: 9.5233 - val_y1_output_root_mean_squared_error: 1.9419 - val_y2_output_root_mean_squared_error: 3.0228
# Epoch 57/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.4403 - y1_output_loss: 2.2506 - y2_output_loss: 5.1284 - y1_output_root_mean_squared_error: 1.5052 - y2_output_root_mean_squared_error: 2.2748 - val_loss: 5.3396 - val_y1_output_loss: 1.5129 - val_y2_output_loss: 3.8139 - val_y1_output_root_mean_squared_error: 1.2439 - val_y2_output_root_mean_squared_error: 1.9474
# Epoch 58/500
# 614/614 [==============================] - 0s 194us/sample - loss: 5.8446 - y1_output_loss: 1.5975 - y2_output_loss: 4.2044 - y1_output_root_mean_squared_error: 1.2689 - y2_output_root_mean_squared_error: 2.0578 - val_loss: 8.4376 - val_y1_output_loss: 2.5169 - val_y2_output_loss: 5.6975 - val_y1_output_root_mean_squared_error: 1.6103 - val_y2_output_root_mean_squared_error: 2.4176
# Epoch 59/500
# 614/614 [==============================] - 0s 144us/sample - loss: 7.0509 - y1_output_loss: 1.7832 - y2_output_loss: 5.2671 - y1_output_root_mean_squared_error: 1.3364 - y2_output_root_mean_squared_error: 2.2946 - val_loss: 13.1903 - val_y1_output_loss: 3.8797 - val_y2_output_loss: 9.7613 - val_y1_output_root_mean_squared_error: 1.9690 - val_y2_output_root_mean_squared_error: 3.0518
# Epoch 60/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.3603 - y1_output_loss: 1.5906 - y2_output_loss: 4.7235 - y1_output_root_mean_squared_error: 1.2652 - y2_output_root_mean_squared_error: 2.1816 - val_loss: 12.3381 - val_y1_output_loss: 3.4869 - val_y2_output_loss: 8.4555 - val_y1_output_root_mean_squared_error: 1.8939 - val_y2_output_root_mean_squared_error: 2.9583
# Epoch 61/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.2428 - y1_output_loss: 1.5206 - y2_output_loss: 3.6922 - y1_output_root_mean_squared_error: 1.2350 - y2_output_root_mean_squared_error: 1.9281 - val_loss: 7.3337 - val_y1_output_loss: 1.1538 - val_y2_output_loss: 6.4652 - val_y1_output_root_mean_squared_error: 1.0857 - val_y2_output_root_mean_squared_error: 2.4809
# Epoch 62/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.1480 - y1_output_loss: 1.2460 - y2_output_loss: 3.8577 - y1_output_root_mean_squared_error: 1.1203 - y2_output_root_mean_squared_error: 1.9730 - val_loss: 4.4435 - val_y1_output_loss: 1.0971 - val_y2_output_loss: 3.3452 - val_y1_output_root_mean_squared_error: 1.0661 - val_y2_output_root_mean_squared_error: 1.8185
# Epoch 63/500
# 614/614 [==============================] - 0s 141us/sample - loss: 8.0729 - y1_output_loss: 2.0515 - y2_output_loss: 6.0164 - y1_output_root_mean_squared_error: 1.4255 - y2_output_root_mean_squared_error: 2.4578 - val_loss: 14.1052 - val_y1_output_loss: 4.4484 - val_y2_output_loss: 9.9893 - val_y1_output_root_mean_squared_error: 2.1053 - val_y2_output_root_mean_squared_error: 3.1101
# Epoch 64/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.4724 - y1_output_loss: 1.6825 - y2_output_loss: 4.7942 - y1_output_root_mean_squared_error: 1.3007 - y2_output_root_mean_squared_error: 2.1865 - val_loss: 7.0205 - val_y1_output_loss: 2.1402 - val_y2_output_loss: 4.9250 - val_y1_output_root_mean_squared_error: 1.4728 - val_y2_output_root_mean_squared_error: 2.2026
# Epoch 65/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.6345 - y1_output_loss: 1.5218 - y2_output_loss: 4.0640 - y1_output_root_mean_squared_error: 1.2378 - y2_output_root_mean_squared_error: 2.0255 - val_loss: 4.1205 - val_y1_output_loss: 0.9677 - val_y2_output_loss: 3.1229 - val_y1_output_root_mean_squared_error: 1.0013 - val_y2_output_root_mean_squared_error: 1.7658
# Epoch 66/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.1220 - y1_output_loss: 0.9742 - y2_output_loss: 3.1660 - y1_output_root_mean_squared_error: 0.9833 - y2_output_root_mean_squared_error: 1.7763 - val_loss: 22.8511 - val_y1_output_loss: 8.2233 - val_y2_output_loss: 15.6378 - val_y1_output_root_mean_squared_error: 2.8200 - val_y2_output_root_mean_squared_error: 3.8599
# Epoch 67/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.1996 - y1_output_loss: 1.2905 - y2_output_loss: 3.9502 - y1_output_root_mean_squared_error: 1.1397 - y2_output_root_mean_squared_error: 1.9750 - val_loss: 12.7476 - val_y1_output_loss: 3.5660 - val_y2_output_loss: 8.8693 - val_y1_output_root_mean_squared_error: 1.9023 - val_y2_output_root_mean_squared_error: 3.0214
# Epoch 68/500
# 614/614 [==============================] - 0s 158us/sample - loss: 5.6313 - y1_output_loss: 1.4293 - y2_output_loss: 4.5737 - y1_output_root_mean_squared_error: 1.1536 - y2_output_root_mean_squared_error: 2.0738 - val_loss: 14.2336 - val_y1_output_loss: 4.2507 - val_y2_output_loss: 10.1303 - val_y1_output_root_mean_squared_error: 2.0829 - val_y2_output_root_mean_squared_error: 3.1457
# Epoch 69/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.9906 - y1_output_loss: 1.0156 - y2_output_loss: 3.0312 - y1_output_root_mean_squared_error: 1.0014 - y2_output_root_mean_squared_error: 1.7286 - val_loss: 28.7257 - val_y1_output_loss: 8.7412 - val_y2_output_loss: 20.5726 - val_y1_output_root_mean_squared_error: 2.9577 - val_y2_output_root_mean_squared_error: 4.4696
# Epoch 70/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.3455 - y1_output_loss: 1.1404 - y2_output_loss: 3.2059 - y1_output_root_mean_squared_error: 1.0684 - y2_output_root_mean_squared_error: 1.7900 - val_loss: 11.5711 - val_y1_output_loss: 2.0858 - val_y2_output_loss: 9.2907 - val_y1_output_root_mean_squared_error: 1.4425 - val_y2_output_root_mean_squared_error: 3.0806
# Epoch 71/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.5034 - y1_output_loss: 1.0044 - y2_output_loss: 3.4740 - y1_output_root_mean_squared_error: 1.0037 - y2_output_root_mean_squared_error: 1.8697 - val_loss: 6.3424 - val_y1_output_loss: 1.7555 - val_y2_output_loss: 4.9019 - val_y1_output_root_mean_squared_error: 1.3147 - val_y2_output_root_mean_squared_error: 2.1480
# Epoch 72/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.8653 - y1_output_loss: 1.1158 - y2_output_loss: 3.7238 - y1_output_root_mean_squared_error: 1.0558 - y2_output_root_mean_squared_error: 1.9366 - val_loss: 3.8321 - val_y1_output_loss: 0.8699 - val_y2_output_loss: 2.9758 - val_y1_output_root_mean_squared_error: 0.9434 - val_y2_output_root_mean_squared_error: 1.7153
# Epoch 73/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.6919 - y1_output_loss: 1.0294 - y2_output_loss: 3.6275 - y1_output_root_mean_squared_error: 1.0174 - y2_output_root_mean_squared_error: 1.9123 - val_loss: 6.3051 - val_y1_output_loss: 1.4031 - val_y2_output_loss: 4.7134 - val_y1_output_root_mean_squared_error: 1.2028 - val_y2_output_root_mean_squared_error: 2.2042
# Epoch 74/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.2049 - y1_output_loss: 0.8628 - y2_output_loss: 3.3016 - y1_output_root_mean_squared_error: 0.9333 - y2_output_root_mean_squared_error: 1.8259 - val_loss: 3.9487 - val_y1_output_loss: 0.7199 - val_y2_output_loss: 3.1429 - val_y1_output_root_mean_squared_error: 0.8545 - val_y2_output_root_mean_squared_error: 1.7940
# Epoch 75/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.0046 - y1_output_loss: 0.7116 - y2_output_loss: 2.2799 - y1_output_root_mean_squared_error: 0.8415 - y2_output_root_mean_squared_error: 1.5154 - val_loss: 4.5229 - val_y1_output_loss: 1.2844 - val_y2_output_loss: 3.2736 - val_y1_output_root_mean_squared_error: 1.1198 - val_y2_output_root_mean_squared_error: 1.8080
# Epoch 76/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.6067 - y1_output_loss: 0.9811 - y2_output_loss: 3.5973 - y1_output_root_mean_squared_error: 0.9935 - y2_output_root_mean_squared_error: 1.9025 - val_loss: 3.7385 - val_y1_output_loss: 0.8383 - val_y2_output_loss: 2.9280 - val_y1_output_root_mean_squared_error: 0.9288 - val_y2_output_root_mean_squared_error: 1.6958
# Epoch 77/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.5916 - y1_output_loss: 0.7886 - y2_output_loss: 2.8161 - y1_output_root_mean_squared_error: 0.8913 - y2_output_root_mean_squared_error: 1.6725 - val_loss: 12.2274 - val_y1_output_loss: 1.2130 - val_y2_output_loss: 10.6821 - val_y1_output_root_mean_squared_error: 1.1145 - val_y2_output_root_mean_squared_error: 3.3144
# Epoch 78/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.3234 - y1_output_loss: 0.5718 - y2_output_loss: 2.8141 - y1_output_root_mean_squared_error: 0.7498 - y2_output_root_mean_squared_error: 1.6617 - val_loss: 6.5151 - val_y1_output_loss: 0.6752 - val_y2_output_loss: 5.6619 - val_y1_output_root_mean_squared_error: 0.8362 - val_y2_output_root_mean_squared_error: 2.4116
# Epoch 79/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.1491 - y1_output_loss: 0.6593 - y2_output_loss: 2.4666 - y1_output_root_mean_squared_error: 0.8156 - y2_output_root_mean_squared_error: 1.5760 - val_loss: 4.7261 - val_y1_output_loss: 1.5901 - val_y2_output_loss: 3.2350 - val_y1_output_root_mean_squared_error: 1.2743 - val_y2_output_root_mean_squared_error: 1.7613
# Epoch 80/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.8683 - y1_output_loss: 0.8662 - y2_output_loss: 3.2520 - y1_output_root_mean_squared_error: 0.8828 - y2_output_root_mean_squared_error: 1.7575 - val_loss: 43.0899 - val_y1_output_loss: 18.3958 - val_y2_output_loss: 26.2845 - val_y1_output_root_mean_squared_error: 4.2165 - val_y2_output_root_mean_squared_error: 5.0310
# Epoch 81/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.4882 - y1_output_loss: 1.4080 - y2_output_loss: 4.0385 - y1_output_root_mean_squared_error: 1.1921 - y2_output_root_mean_squared_error: 2.0167 - val_loss: 2.8349 - val_y1_output_loss: 0.4974 - val_y2_output_loss: 2.3214 - val_y1_output_root_mean_squared_error: 0.7181 - val_y2_output_root_mean_squared_error: 1.5229
# Epoch 82/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.6995 - y1_output_loss: 0.6002 - y2_output_loss: 2.1431 - y1_output_root_mean_squared_error: 0.7763 - y2_output_root_mean_squared_error: 1.4481 - val_loss: 16.5366 - val_y1_output_loss: 2.0668 - val_y2_output_loss: 14.3502 - val_y1_output_root_mean_squared_error: 1.4184 - val_y2_output_root_mean_squared_error: 3.8111
# Epoch 83/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.8186 - y1_output_loss: 1.0306 - y2_output_loss: 3.7631 - y1_output_root_mean_squared_error: 1.0182 - y2_output_root_mean_squared_error: 1.9447 - val_loss: 3.1783 - val_y1_output_loss: 0.6146 - val_y2_output_loss: 2.5431 - val_y1_output_root_mean_squared_error: 0.7886 - val_y2_output_root_mean_squared_error: 1.5989
# Epoch 84/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.0926 - y1_output_loss: 0.5917 - y2_output_loss: 2.4763 - y1_output_root_mean_squared_error: 0.7711 - y2_output_root_mean_squared_error: 1.5805 - val_loss: 3.0430 - val_y1_output_loss: 0.7410 - val_y2_output_loss: 2.2845 - val_y1_output_root_mean_squared_error: 0.8732 - val_y2_output_root_mean_squared_error: 1.5101
# Epoch 85/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.4140 - y1_output_loss: 0.9226 - y2_output_loss: 3.5471 - y1_output_root_mean_squared_error: 0.9623 - y2_output_root_mean_squared_error: 1.8676 - val_loss: 8.3832 - val_y1_output_loss: 1.0514 - val_y2_output_loss: 7.0930 - val_y1_output_root_mean_squared_error: 1.0304 - val_y2_output_root_mean_squared_error: 2.7058
# Epoch 86/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.2477 - y1_output_loss: 0.6674 - y2_output_loss: 2.5813 - y1_output_root_mean_squared_error: 0.8188 - y2_output_root_mean_squared_error: 1.6054 - val_loss: 3.6233 - val_y1_output_loss: 0.6128 - val_y2_output_loss: 3.0297 - val_y1_output_root_mean_squared_error: 0.7916 - val_y2_output_root_mean_squared_error: 1.7311
# Epoch 87/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.3825 - y1_output_loss: 0.8061 - y2_output_loss: 3.5391 - y1_output_root_mean_squared_error: 0.9012 - y2_output_root_mean_squared_error: 1.8895 - val_loss: 2.9987 - val_y1_output_loss: 0.5380 - val_y2_output_loss: 2.4867 - val_y1_output_root_mean_squared_error: 0.7444 - val_y2_output_root_mean_squared_error: 1.5635
# Epoch 88/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.9320 - y1_output_loss: 0.6073 - y2_output_loss: 2.3011 - y1_output_root_mean_squared_error: 0.7803 - y2_output_root_mean_squared_error: 1.5242 - val_loss: 3.0095 - val_y1_output_loss: 0.8842 - val_y2_output_loss: 2.1832 - val_y1_output_root_mean_squared_error: 0.9425 - val_y2_output_root_mean_squared_error: 1.4564
# Epoch 89/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.2261 - y1_output_loss: 0.5643 - y2_output_loss: 2.6436 - y1_output_root_mean_squared_error: 0.7487 - y2_output_root_mean_squared_error: 1.6327 - val_loss: 2.6664 - val_y1_output_loss: 0.5823 - val_y2_output_loss: 2.1038 - val_y1_output_root_mean_squared_error: 0.7723 - val_y2_output_root_mean_squared_error: 1.4388
# Epoch 90/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.4786 - y1_output_loss: 0.6143 - y2_output_loss: 2.8351 - y1_output_root_mean_squared_error: 0.7849 - y2_output_root_mean_squared_error: 1.6919 - val_loss: 4.7077 - val_y1_output_loss: 1.1613 - val_y2_output_loss: 3.5056 - val_y1_output_root_mean_squared_error: 1.0684 - val_y2_output_root_mean_squared_error: 1.8884
# Epoch 91/500
# 614/614 [==============================] - 0s 199us/sample - loss: 2.7764 - y1_output_loss: 0.5500 - y2_output_loss: 2.2422 - y1_output_root_mean_squared_error: 0.7441 - y2_output_root_mean_squared_error: 1.4909 - val_loss: 2.6645 - val_y1_output_loss: 0.5010 - val_y2_output_loss: 2.1691 - val_y1_output_root_mean_squared_error: 0.7132 - val_y2_output_root_mean_squared_error: 1.4683
# Epoch 92/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.6221 - y1_output_loss: 1.1759 - y2_output_loss: 3.4351 - y1_output_root_mean_squared_error: 1.0855 - y2_output_root_mean_squared_error: 1.8557 - val_loss: 10.4299 - val_y1_output_loss: 3.2657 - val_y2_output_loss: 7.5442 - val_y1_output_root_mean_squared_error: 1.7878 - val_y2_output_root_mean_squared_error: 2.6895
# Epoch 93/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.6649 - y1_output_loss: 0.8304 - y2_output_loss: 2.8779 - y1_output_root_mean_squared_error: 0.9143 - y2_output_root_mean_squared_error: 1.6819 - val_loss: 7.8176 - val_y1_output_loss: 1.0039 - val_y2_output_loss: 6.6301 - val_y1_output_root_mean_squared_error: 1.0013 - val_y2_output_root_mean_squared_error: 2.6106
# Epoch 94/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.1779 - y1_output_loss: 0.6484 - y2_output_loss: 2.5109 - y1_output_root_mean_squared_error: 0.8089 - y2_output_root_mean_squared_error: 1.5886 - val_loss: 3.2044 - val_y1_output_loss: 0.8368 - val_y2_output_loss: 2.3659 - val_y1_output_root_mean_squared_error: 0.9175 - val_y2_output_root_mean_squared_error: 1.5371
# Epoch 95/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.9075 - y1_output_loss: 0.5738 - y2_output_loss: 2.3485 - y1_output_root_mean_squared_error: 0.7580 - y2_output_root_mean_squared_error: 1.5274 - val_loss: 6.2101 - val_y1_output_loss: 2.5925 - val_y2_output_loss: 3.8503 - val_y1_output_root_mean_squared_error: 1.5934 - val_y2_output_root_mean_squared_error: 1.9160
# Epoch 96/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.1012 - y1_output_loss: 0.6215 - y2_output_loss: 2.4931 - y1_output_root_mean_squared_error: 0.7844 - y2_output_root_mean_squared_error: 1.5767 - val_loss: 5.8965 - val_y1_output_loss: 0.9052 - val_y2_output_loss: 4.7881 - val_y1_output_root_mean_squared_error: 0.9634 - val_y2_output_root_mean_squared_error: 2.2290
# Epoch 97/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.4668 - y1_output_loss: 0.5493 - y2_output_loss: 1.9222 - y1_output_root_mean_squared_error: 0.7442 - y2_output_root_mean_squared_error: 1.3831 - val_loss: 4.7466 - val_y1_output_loss: 0.7546 - val_y2_output_loss: 3.8659 - val_y1_output_root_mean_squared_error: 0.8693 - val_y2_output_root_mean_squared_error: 1.9977
# Epoch 98/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.3063 - y1_output_loss: 0.6806 - y2_output_loss: 2.6366 - y1_output_root_mean_squared_error: 0.8274 - y2_output_root_mean_squared_error: 1.6192 - val_loss: 3.1903 - val_y1_output_loss: 0.8718 - val_y2_output_loss: 2.3208 - val_y1_output_root_mean_squared_error: 0.9495 - val_y2_output_root_mean_squared_error: 1.5128
# Epoch 99/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.0588 - y1_output_loss: 0.6348 - y2_output_loss: 2.4346 - y1_output_root_mean_squared_error: 0.7992 - y2_output_root_mean_squared_error: 1.5556 - val_loss: 5.2073 - val_y1_output_loss: 0.5206 - val_y2_output_loss: 4.5255 - val_y1_output_root_mean_squared_error: 0.7292 - val_y2_output_root_mean_squared_error: 2.1623
# Epoch 100/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.7703 - y1_output_loss: 0.5096 - y2_output_loss: 2.2598 - y1_output_root_mean_squared_error: 0.7158 - y2_output_root_mean_squared_error: 1.5027 - val_loss: 4.4795 - val_y1_output_loss: 0.9853 - val_y2_output_loss: 3.4088 - val_y1_output_root_mean_squared_error: 0.9832 - val_y2_output_root_mean_squared_error: 1.8742
# Epoch 101/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.7243 - y1_output_loss: 0.4630 - y2_output_loss: 2.2549 - y1_output_root_mean_squared_error: 0.6746 - y2_output_root_mean_squared_error: 1.5064 - val_loss: 7.8859 - val_y1_output_loss: 2.3232 - val_y2_output_loss: 5.7619 - val_y1_output_root_mean_squared_error: 1.5195 - val_y2_output_root_mean_squared_error: 2.3616
# Epoch 102/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.3293 - y1_output_loss: 0.8136 - y2_output_loss: 2.5128 - y1_output_root_mean_squared_error: 0.9038 - y2_output_root_mean_squared_error: 1.5851 - val_loss: 4.1071 - val_y1_output_loss: 1.5898 - val_y2_output_loss: 2.5691 - val_y1_output_root_mean_squared_error: 1.2504 - val_y2_output_root_mean_squared_error: 1.5948
# Epoch 103/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.4911 - y1_output_loss: 0.5943 - y2_output_loss: 1.9272 - y1_output_root_mean_squared_error: 0.7619 - y2_output_root_mean_squared_error: 1.3822 - val_loss: 7.8386 - val_y1_output_loss: 3.2236 - val_y2_output_loss: 4.9627 - val_y1_output_root_mean_squared_error: 1.7582 - val_y2_output_root_mean_squared_error: 2.1789
# Epoch 104/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.8773 - y1_output_loss: 0.5971 - y2_output_loss: 2.2571 - y1_output_root_mean_squared_error: 0.7749 - y2_output_root_mean_squared_error: 1.5089 - val_loss: 2.3477 - val_y1_output_loss: 0.4040 - val_y2_output_loss: 1.9423 - val_y1_output_root_mean_squared_error: 0.6367 - val_y2_output_root_mean_squared_error: 1.3937
# Epoch 105/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.9027 - y1_output_loss: 0.5370 - y2_output_loss: 2.3406 - y1_output_root_mean_squared_error: 0.7357 - y2_output_root_mean_squared_error: 1.5367 - val_loss: 2.7242 - val_y1_output_loss: 0.5564 - val_y2_output_loss: 2.1164 - val_y1_output_root_mean_squared_error: 0.7486 - val_y2_output_root_mean_squared_error: 1.4710
# Epoch 106/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.1849 - y1_output_loss: 0.7510 - y2_output_loss: 2.4078 - y1_output_root_mean_squared_error: 0.8698 - y2_output_root_mean_squared_error: 1.5583 - val_loss: 3.0689 - val_y1_output_loss: 0.5064 - val_y2_output_loss: 2.4935 - val_y1_output_root_mean_squared_error: 0.7131 - val_y2_output_root_mean_squared_error: 1.6001
# Epoch 107/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.6507 - y1_output_loss: 0.6074 - y2_output_loss: 2.0292 - y1_output_root_mean_squared_error: 0.7805 - y2_output_root_mean_squared_error: 1.4289 - val_loss: 4.1690 - val_y1_output_loss: 1.5472 - val_y2_output_loss: 2.6152 - val_y1_output_root_mean_squared_error: 1.2401 - val_y2_output_root_mean_squared_error: 1.6221
# Epoch 108/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.7412 - y1_output_loss: 0.5514 - y2_output_loss: 2.1772 - y1_output_root_mean_squared_error: 0.7437 - y2_output_root_mean_squared_error: 1.4792 - val_loss: 3.3914 - val_y1_output_loss: 0.6372 - val_y2_output_loss: 2.6729 - val_y1_output_root_mean_squared_error: 0.8000 - val_y2_output_root_mean_squared_error: 1.6587
# Epoch 109/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.4986 - y1_output_loss: 0.5297 - y2_output_loss: 1.9502 - y1_output_root_mean_squared_error: 0.7309 - y2_output_root_mean_squared_error: 1.4016 - val_loss: 2.3831 - val_y1_output_loss: 0.5271 - val_y2_output_loss: 1.8481 - val_y1_output_root_mean_squared_error: 0.7240 - val_y2_output_root_mean_squared_error: 1.3634
# Epoch 110/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.4041 - y1_output_loss: 0.5134 - y2_output_loss: 1.9048 - y1_output_root_mean_squared_error: 0.7091 - y2_output_root_mean_squared_error: 1.3789 - val_loss: 10.0268 - val_y1_output_loss: 2.1726 - val_y2_output_loss: 7.6689 - val_y1_output_root_mean_squared_error: 1.4815 - val_y2_output_root_mean_squared_error: 2.7985
# Epoch 111/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.1342 - y1_output_loss: 0.6580 - y2_output_loss: 2.4480 - y1_output_root_mean_squared_error: 0.8146 - y2_output_root_mean_squared_error: 1.5718 - val_loss: 2.1297 - val_y1_output_loss: 0.4252 - val_y2_output_loss: 1.6876 - val_y1_output_root_mean_squared_error: 0.6608 - val_y2_output_root_mean_squared_error: 1.3011
# Epoch 112/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.3549 - y1_output_loss: 0.7040 - y2_output_loss: 2.6407 - y1_output_root_mean_squared_error: 0.8412 - y2_output_root_mean_squared_error: 1.6270 - val_loss: 2.3503 - val_y1_output_loss: 0.4558 - val_y2_output_loss: 1.8562 - val_y1_output_root_mean_squared_error: 0.6753 - val_y2_output_root_mean_squared_error: 1.3763
# Epoch 113/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.3626 - y1_output_loss: 0.5304 - y2_output_loss: 1.8294 - y1_output_root_mean_squared_error: 0.7278 - y2_output_root_mean_squared_error: 1.3539 - val_loss: 5.1252 - val_y1_output_loss: 0.5093 - val_y2_output_loss: 4.5024 - val_y1_output_root_mean_squared_error: 0.7178 - val_y2_output_root_mean_squared_error: 2.1471
# Epoch 114/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.0024 - y1_output_loss: 0.6611 - y2_output_loss: 2.3234 - y1_output_root_mean_squared_error: 0.8152 - y2_output_root_mean_squared_error: 1.5290 - val_loss: 3.1270 - val_y1_output_loss: 0.3889 - val_y2_output_loss: 2.7974 - val_y1_output_root_mean_squared_error: 0.6316 - val_y2_output_root_mean_squared_error: 1.6517
# Epoch 115/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.4191 - y1_output_loss: 0.4652 - y2_output_loss: 1.9405 - y1_output_root_mean_squared_error: 0.6837 - y2_output_root_mean_squared_error: 1.3970 - val_loss: 2.4319 - val_y1_output_loss: 0.5076 - val_y2_output_loss: 1.9023 - val_y1_output_root_mean_squared_error: 0.7167 - val_y2_output_root_mean_squared_error: 1.3850
# Epoch 116/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.4694 - y1_output_loss: 0.8827 - y2_output_loss: 2.6057 - y1_output_root_mean_squared_error: 0.9434 - y2_output_root_mean_squared_error: 1.6061 - val_loss: 4.0804 - val_y1_output_loss: 0.8863 - val_y2_output_loss: 3.1859 - val_y1_output_root_mean_squared_error: 0.9594 - val_y2_output_root_mean_squared_error: 1.7776
# Epoch 117/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.4029 - y1_output_loss: 0.5220 - y2_output_loss: 1.8721 - y1_output_root_mean_squared_error: 0.7245 - y2_output_root_mean_squared_error: 1.3704 - val_loss: 4.3419 - val_y1_output_loss: 0.9940 - val_y2_output_loss: 3.4289 - val_y1_output_root_mean_squared_error: 0.9959 - val_y2_output_root_mean_squared_error: 1.8303
# Epoch 118/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.5787 - y1_output_loss: 0.5703 - y2_output_loss: 1.9888 - y1_output_root_mean_squared_error: 0.7559 - y2_output_root_mean_squared_error: 1.4168 - val_loss: 5.4249 - val_y1_output_loss: 1.3884 - val_y2_output_loss: 4.2289 - val_y1_output_root_mean_squared_error: 1.1756 - val_y2_output_root_mean_squared_error: 2.0107
# Epoch 119/500
# 614/614 [==============================] - 0s 167us/sample - loss: 2.5933 - y1_output_loss: 0.5858 - y2_output_loss: 1.9953 - y1_output_root_mean_squared_error: 0.7647 - y2_output_root_mean_squared_error: 1.4172 - val_loss: 3.2608 - val_y1_output_loss: 0.7041 - val_y2_output_loss: 2.4892 - val_y1_output_root_mean_squared_error: 0.8388 - val_y2_output_root_mean_squared_error: 1.5991
# Epoch 120/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.5271 - y1_output_loss: 0.4854 - y2_output_loss: 2.0544 - y1_output_root_mean_squared_error: 0.6997 - y2_output_root_mean_squared_error: 1.4274 - val_loss: 3.5790 - val_y1_output_loss: 0.5774 - val_y2_output_loss: 2.8999 - val_y1_output_root_mean_squared_error: 0.7641 - val_y2_output_root_mean_squared_error: 1.7306
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4161 - y1_output_loss: 0.1173 - y2_output_loss: 0.2999 - y1_output_root_mean_squared_error: 0.3393 - y2_output_root_mean_squared_error: 0.5486 - val_loss: 1.4310 - val_y1_output_loss: 0.3748 - val_y2_output_loss: 1.0171 - val_y1_output_root_mean_squared_error: 0.6164 - val_y2_output_root_mean_squared_error: 1.0252
# Epoch 462/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3788 - y1_output_loss: 0.1023 - y2_output_loss: 0.2771 - y1_output_root_mean_squared_error: 0.3191 - y2_output_root_mean_squared_error: 0.5263 - val_loss: 1.6258 - val_y1_output_loss: 0.2891 - val_y2_output_loss: 1.3018 - val_y1_output_root_mean_squared_error: 0.5360 - val_y2_output_root_mean_squared_error: 1.1569
# Epoch 463/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.5983 - y1_output_loss: 0.1339 - y2_output_loss: 0.4595 - y1_output_root_mean_squared_error: 0.3672 - y2_output_root_mean_squared_error: 0.6808 - val_loss: 0.9877 - val_y1_output_loss: 0.2259 - val_y2_output_loss: 0.7600 - val_y1_output_root_mean_squared_error: 0.4827 - val_y2_output_root_mean_squared_error: 0.8687
# Epoch 464/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4651 - y1_output_loss: 0.1188 - y2_output_loss: 0.3432 - y1_output_root_mean_squared_error: 0.3452 - y2_output_root_mean_squared_error: 0.5882 - val_loss: 1.0479 - val_y1_output_loss: 0.2524 - val_y2_output_loss: 0.8167 - val_y1_output_root_mean_squared_error: 0.5044 - val_y2_output_root_mean_squared_error: 0.8908
# Epoch 465/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5226 - y1_output_loss: 0.1162 - y2_output_loss: 0.4049 - y1_output_root_mean_squared_error: 0.3422 - y2_output_root_mean_squared_error: 0.6368 - val_loss: 0.8917 - val_y1_output_loss: 0.1820 - val_y2_output_loss: 0.7079 - val_y1_output_root_mean_squared_error: 0.4329 - val_y2_output_root_mean_squared_error: 0.8392
# Epoch 466/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3826 - y1_output_loss: 0.1106 - y2_output_loss: 0.2732 - y1_output_root_mean_squared_error: 0.3308 - y2_output_root_mean_squared_error: 0.5227 - val_loss: 1.2334 - val_y1_output_loss: 0.3166 - val_y2_output_loss: 0.8904 - val_y1_output_root_mean_squared_error: 0.5653 - val_y2_output_root_mean_squared_error: 0.9560
# Epoch 467/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3970 - y1_output_loss: 0.1172 - y2_output_loss: 0.2778 - y1_output_root_mean_squared_error: 0.3436 - y2_output_root_mean_squared_error: 0.5281 - val_loss: 1.0128 - val_y1_output_loss: 0.1992 - val_y2_output_loss: 0.7833 - val_y1_output_root_mean_squared_error: 0.4496 - val_y2_output_root_mean_squared_error: 0.9004
# Epoch 468/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4007 - y1_output_loss: 0.1125 - y2_output_loss: 0.2887 - y1_output_root_mean_squared_error: 0.3333 - y2_output_root_mean_squared_error: 0.5382 - val_loss: 0.9108 - val_y1_output_loss: 0.2404 - val_y2_output_loss: 0.6671 - val_y1_output_root_mean_squared_error: 0.4951 - val_y2_output_root_mean_squared_error: 0.8158
# Epoch 469/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4813 - y1_output_loss: 0.1211 - y2_output_loss: 0.3574 - y1_output_root_mean_squared_error: 0.3483 - y2_output_root_mean_squared_error: 0.6000 - val_loss: 1.1893 - val_y1_output_loss: 0.2595 - val_y2_output_loss: 0.9676 - val_y1_output_root_mean_squared_error: 0.5110 - val_y2_output_root_mean_squared_error: 0.9634
# Epoch 470/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5179 - y1_output_loss: 0.1249 - y2_output_loss: 0.3897 - y1_output_root_mean_squared_error: 0.3540 - y2_output_root_mean_squared_error: 0.6266 - val_loss: 0.9394 - val_y1_output_loss: 0.2103 - val_y2_output_loss: 0.7256 - val_y1_output_root_mean_squared_error: 0.4655 - val_y2_output_root_mean_squared_error: 0.8502
# Epoch 471/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4296 - y1_output_loss: 0.1201 - y2_output_loss: 0.3171 - y1_output_root_mean_squared_error: 0.3423 - y2_output_root_mean_squared_error: 0.5589 - val_loss: 1.1827 - val_y1_output_loss: 0.2259 - val_y2_output_loss: 0.9402 - val_y1_output_root_mean_squared_error: 0.4787 - val_y2_output_root_mean_squared_error: 0.9765
# Epoch 472/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.7076 - y1_output_loss: 0.1329 - y2_output_loss: 0.5743 - y1_output_root_mean_squared_error: 0.3643 - y2_output_root_mean_squared_error: 0.7582 - val_loss: 1.4372 - val_y1_output_loss: 0.1981 - val_y2_output_loss: 1.1910 - val_y1_output_root_mean_squared_error: 0.4504 - val_y2_output_root_mean_squared_error: 1.1110
# Epoch 473/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4295 - y1_output_loss: 0.1034 - y2_output_loss: 0.3286 - y1_output_root_mean_squared_error: 0.3181 - y2_output_root_mean_squared_error: 0.5730 - val_loss: 1.0777 - val_y1_output_loss: 0.2267 - val_y2_output_loss: 0.8205 - val_y1_output_root_mean_squared_error: 0.4841 - val_y2_output_root_mean_squared_error: 0.9183
# Epoch 474/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4835 - y1_output_loss: 0.1394 - y2_output_loss: 0.3561 - y1_output_root_mean_squared_error: 0.3687 - y2_output_root_mean_squared_error: 0.5895 - val_loss: 3.5303 - val_y1_output_loss: 0.4987 - val_y2_output_loss: 3.0600 - val_y1_output_root_mean_squared_error: 0.7128 - val_y2_output_root_mean_squared_error: 1.7385
# Epoch 475/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4206 - y1_output_loss: 0.1153 - y2_output_loss: 0.3086 - y1_output_root_mean_squared_error: 0.3389 - y2_output_root_mean_squared_error: 0.5530 - val_loss: 1.1497 - val_y1_output_loss: 0.2039 - val_y2_output_loss: 0.9146 - val_y1_output_root_mean_squared_error: 0.4589 - val_y2_output_root_mean_squared_error: 0.9691
# Epoch 476/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.5270 - y1_output_loss: 0.1294 - y2_output_loss: 0.3945 - y1_output_root_mean_squared_error: 0.3609 - y2_output_root_mean_squared_error: 0.6299 - val_loss: 0.8379 - val_y1_output_loss: 0.1867 - val_y2_output_loss: 0.6351 - val_y1_output_root_mean_squared_error: 0.4377 - val_y2_output_root_mean_squared_error: 0.8040
# Epoch 477/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4336 - y1_output_loss: 0.1189 - y2_output_loss: 0.3160 - y1_output_root_mean_squared_error: 0.3459 - y2_output_root_mean_squared_error: 0.5603 - val_loss: 1.1362 - val_y1_output_loss: 0.1978 - val_y2_output_loss: 0.9947 - val_y1_output_root_mean_squared_error: 0.4489 - val_y2_output_root_mean_squared_error: 0.9668
# Epoch 478/500
# 614/614 [==============================] - 0s 179us/sample - loss: 0.3640 - y1_output_loss: 0.0912 - y2_output_loss: 0.2789 - y1_output_root_mean_squared_error: 0.2982 - y2_output_root_mean_squared_error: 0.5244 - val_loss: 1.1010 - val_y1_output_loss: 0.2642 - val_y2_output_loss: 0.8188 - val_y1_output_root_mean_squared_error: 0.5149 - val_y2_output_root_mean_squared_error: 0.9143
# Epoch 479/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.6640 - y1_output_loss: 0.1554 - y2_output_loss: 0.5050 - y1_output_root_mean_squared_error: 0.3960 - y2_output_root_mean_squared_error: 0.7122 - val_loss: 1.0034 - val_y1_output_loss: 0.2261 - val_y2_output_loss: 0.7490 - val_y1_output_root_mean_squared_error: 0.4780 - val_y2_output_root_mean_squared_error: 0.8803
# Epoch 480/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3754 - y1_output_loss: 0.1066 - y2_output_loss: 0.2673 - y1_output_root_mean_squared_error: 0.3256 - y2_output_root_mean_squared_error: 0.5191 - val_loss: 1.3380 - val_y1_output_loss: 0.2205 - val_y2_output_loss: 1.0799 - val_y1_output_root_mean_squared_error: 0.4739 - val_y2_output_root_mean_squared_error: 1.0552
# Epoch 481/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4667 - y1_output_loss: 0.1232 - y2_output_loss: 0.3434 - y1_output_root_mean_squared_error: 0.3492 - y2_output_root_mean_squared_error: 0.5872 - val_loss: 1.1641 - val_y1_output_loss: 0.4506 - val_y2_output_loss: 0.7634 - val_y1_output_root_mean_squared_error: 0.6632 - val_y2_output_root_mean_squared_error: 0.8510
# Epoch 482/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.2921 - y1_output_loss: 0.0939 - y2_output_loss: 0.1958 - y1_output_root_mean_squared_error: 0.3077 - y2_output_root_mean_squared_error: 0.4443 - val_loss: 0.8380 - val_y1_output_loss: 0.2032 - val_y2_output_loss: 0.6303 - val_y1_output_root_mean_squared_error: 0.4560 - val_y2_output_root_mean_squared_error: 0.7938
# Epoch 483/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3873 - y1_output_loss: 0.0961 - y2_output_loss: 0.2925 - y1_output_root_mean_squared_error: 0.3112 - y2_output_root_mean_squared_error: 0.5389 - val_loss: 0.9869 - val_y1_output_loss: 0.1816 - val_y2_output_loss: 0.7782 - val_y1_output_root_mean_squared_error: 0.4326 - val_y2_output_root_mean_squared_error: 0.8943
# Epoch 484/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3556 - y1_output_loss: 0.1033 - y2_output_loss: 0.2521 - y1_output_root_mean_squared_error: 0.3218 - y2_output_root_mean_squared_error: 0.5021 - val_loss: 1.2573 - val_y1_output_loss: 0.2487 - val_y2_output_loss: 0.9775 - val_y1_output_root_mean_squared_error: 0.5029 - val_y2_output_root_mean_squared_error: 1.0022
# Epoch 485/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.7685 - y1_output_loss: 0.1629 - y2_output_loss: 0.6015 - y1_output_root_mean_squared_error: 0.4039 - y2_output_root_mean_squared_error: 0.7780 - val_loss: 1.6082 - val_y1_output_loss: 0.3081 - val_y2_output_loss: 1.2656 - val_y1_output_root_mean_squared_error: 0.5584 - val_y2_output_root_mean_squared_error: 1.1386
# Epoch 486/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4735 - y1_output_loss: 0.1270 - y2_output_loss: 0.3551 - y1_output_root_mean_squared_error: 0.3493 - y2_output_root_mean_squared_error: 0.5929 - val_loss: 2.8120 - val_y1_output_loss: 1.1117 - val_y2_output_loss: 1.8444 - val_y1_output_root_mean_squared_error: 1.0369 - val_y2_output_root_mean_squared_error: 1.3178
# Epoch 487/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.5188 - y1_output_loss: 0.1279 - y2_output_loss: 0.3874 - y1_output_root_mean_squared_error: 0.3594 - y2_output_root_mean_squared_error: 0.6242 - val_loss: 0.8993 - val_y1_output_loss: 0.1836 - val_y2_output_loss: 0.6948 - val_y1_output_root_mean_squared_error: 0.4361 - val_y2_output_root_mean_squared_error: 0.8421
# Epoch 488/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4071 - y1_output_loss: 0.1193 - y2_output_loss: 0.2953 - y1_output_root_mean_squared_error: 0.3461 - y2_output_root_mean_squared_error: 0.5361 - val_loss: 2.1826 - val_y1_output_loss: 0.2795 - val_y2_output_loss: 1.8599 - val_y1_output_root_mean_squared_error: 0.5295 - val_y2_output_root_mean_squared_error: 1.3792
# Epoch 489/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4282 - y1_output_loss: 0.1173 - y2_output_loss: 0.3106 - y1_output_root_mean_squared_error: 0.3438 - y2_output_root_mean_squared_error: 0.5568 - val_loss: 0.9923 - val_y1_output_loss: 0.2040 - val_y2_output_loss: 0.7694 - val_y1_output_root_mean_squared_error: 0.4564 - val_y2_output_root_mean_squared_error: 0.8854
# Epoch 490/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4473 - y1_output_loss: 0.1298 - y2_output_loss: 0.3189 - y1_output_root_mean_squared_error: 0.3600 - y2_output_root_mean_squared_error: 0.5637 - val_loss: 1.6750 - val_y1_output_loss: 0.4751 - val_y2_output_loss: 1.1688 - val_y1_output_root_mean_squared_error: 0.6834 - val_y2_output_root_mean_squared_error: 1.0991
# Epoch 491/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3337 - y1_output_loss: 0.1045 - y2_output_loss: 0.2274 - y1_output_root_mean_squared_error: 0.3241 - y2_output_root_mean_squared_error: 0.4782 - val_loss: 0.9690 - val_y1_output_loss: 0.2396 - val_y2_output_loss: 0.7150 - val_y1_output_root_mean_squared_error: 0.4944 - val_y2_output_root_mean_squared_error: 0.8512
# Epoch 492/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4708 - y1_output_loss: 0.1271 - y2_output_loss: 0.3480 - y1_output_root_mean_squared_error: 0.3535 - y2_output_root_mean_squared_error: 0.5881 - val_loss: 1.3625 - val_y1_output_loss: 0.2890 - val_y2_output_loss: 1.0550 - val_y1_output_root_mean_squared_error: 0.5419 - val_y2_output_root_mean_squared_error: 1.0338
# Epoch 493/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4034 - y1_output_loss: 0.1123 - y2_output_loss: 0.2885 - y1_output_root_mean_squared_error: 0.3363 - y2_output_root_mean_squared_error: 0.5388 - val_loss: 0.8306 - val_y1_output_loss: 0.1763 - val_y2_output_loss: 0.6318 - val_y1_output_root_mean_squared_error: 0.4277 - val_y2_output_root_mean_squared_error: 0.8048
# Epoch 494/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4389 - y1_output_loss: 0.1241 - y2_output_loss: 0.3178 - y1_output_root_mean_squared_error: 0.3520 - y2_output_root_mean_squared_error: 0.5613 - val_loss: 1.3095 - val_y1_output_loss: 0.2046 - val_y2_output_loss: 1.0979 - val_y1_output_root_mean_squared_error: 0.4588 - val_y2_output_root_mean_squared_error: 1.0483
# Epoch 495/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.5026 - y1_output_loss: 0.1237 - y2_output_loss: 0.3760 - y1_output_root_mean_squared_error: 0.3530 - y2_output_root_mean_squared_error: 0.6148 - val_loss: 0.8388 - val_y1_output_loss: 0.1844 - val_y2_output_loss: 0.6478 - val_y1_output_root_mean_squared_error: 0.4360 - val_y2_output_root_mean_squared_error: 0.8054
# Epoch 496/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.5660 - y1_output_loss: 0.1377 - y2_output_loss: 0.4270 - y1_output_root_mean_squared_error: 0.3725 - y2_output_root_mean_squared_error: 0.6536 - val_loss: 1.0573 - val_y1_output_loss: 0.2554 - val_y2_output_loss: 0.7714 - val_y1_output_root_mean_squared_error: 0.5140 - val_y2_output_root_mean_squared_error: 0.8905
# Epoch 497/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4447 - y1_output_loss: 0.1223 - y2_output_loss: 0.3220 - y1_output_root_mean_squared_error: 0.3497 - y2_output_root_mean_squared_error: 0.5678 - val_loss: 0.9063 - val_y1_output_loss: 0.1915 - val_y2_output_loss: 0.7018 - val_y1_output_root_mean_squared_error: 0.4446 - val_y2_output_root_mean_squared_error: 0.8418
# Epoch 498/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4863 - y1_output_loss: 0.1398 - y2_output_loss: 0.3447 - y1_output_root_mean_squared_error: 0.3734 - y2_output_root_mean_squared_error: 0.5890 - val_loss: 1.0208 - val_y1_output_loss: 0.2366 - val_y2_output_loss: 0.7894 - val_y1_output_root_mean_squared_error: 0.4943 - val_y2_output_root_mean_squared_error: 0.8812
# Epoch 499/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4188 - y1_output_loss: 0.1079 - y2_output_loss: 0.3094 - y1_output_root_mean_squared_error: 0.3266 - y2_output_root_mean_squared_error: 0.5587 - val_loss: 1.1450 - val_y1_output_loss: 0.3017 - val_y2_output_loss: 0.8161 - val_y1_output_root_mean_squared_error: 0.5521 - val_y2_output_root_mean_squared_error: 0.9167
# Epoch 500/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4641 - y1_output_loss: 0.1287 - y2_output_loss: 0.3342 - y1_output_root_mean_squared_error: 0.3576 - y2_output_root_mean_squared_error: 0.5798 - val_loss: 0.9774 - val_y1_output_loss: 0.2449 - val_y2_output_loss: 0.7167 - val_y1_output_root_mean_squared_error: 0.5016 - val_y2_output_root_mean_squared_error: 0.8519

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 38us/sample - loss: 0.9774 - y1_output_loss: 0.2501 - y2_output_loss: 0.7313 - y1_output_root_mean_squared_error: 0.5016 - y2_output_root_mean_squared_error: 0.8519
# Loss = 0.9774102607330719, Y1_loss = 0.25007522106170654, Y1_mse = 0.5016137361526489, Y2_loss = 0.7312759160995483, Y2_mse = 0.8519354462623596

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
